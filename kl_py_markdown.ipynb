# %% [markdown]
# <a href="https://colab.research.google.com/github/klajosw/python/blob/master/kl_py_markdown.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p align="left">
#     <img src="https://raw.githubusercontent.com/klajosw/python/master/kl_mie_python_logo_250.jpg"
#          align="left" width="251" height="251">
#
# </p>
#
#
# <p> </p>
#
#
#
# # Markdown cellák és jelőlők használata
#
# <https://klajosw.blogspot.com/>
#
#
# ---

# %% [markdown]
# A [Markdown](https://en.wikipedia.org/wiki/Markdown) egy webes "könnyen" írható, "könnyen" olvasható formátum, mely tipikusan böngészőben megjelenített szövegek, dokumentumok gyors szerkesztését teszi lehetővé.
#
# Az általam használt [jupyter](http://jupyter.org/) keretrendszer Markdown formátumú celláiba legtöbször az adott porgramozási feladattal kapcsolatos feladatok leírása kerül.
#
# Ezen kívül ha a feladat szövege megköveteli, hogy szavakban fejezzük ki a program megírása során szerzett tapasztalatainkat, akkor ezeket a gondolatokat is Markdown cellákba kell leírni!
#
#
# A Markdown egy speciális szintaktikai elemekből felépített szövegfájl alapú dokumentum. Kiterjesztései általában *.md ( *.markdown )
#
# Használatával egy egyszerű text fájl szerkesztésével, melyben néhány vezérlő karaktert helyezünk el formázott megjelenésű dokumentum állítható elő...
#
# Az Internetes közösségek által most a legjobbnak tartott ingyenes több platformos program a Typora https://typora.io/, mivel a beírt formázási kódok eredményét azonnal mutatja.
#
#
#
# ## Az alábbiakban tekintsük át a Markdown formátum alapjait.

# %% [markdown]
# ## Szövegszerkesztés, kiemelések
#
#
# Új sor jelőlése :  \<br\>
#
# Ezt írd be:
# ```
# sor<br>újsor<br>másik ujsor
# ```
#
# ez látható:
# sor<br>újsor<br>másik ujsor

# %% [markdown]
# ## Címsorok
#
# Egy teljes notebook vagy egy szövegrész címeit Markdownban a \#-jellel jelöljük.
#
# Egy \# jelölheti például a teljes notebook címét, két \# egy fejezet címét.
#
# Egyre több \# pedig a dokumentum tagolásának egyre mélyebb szerkezeti egységeit.
#
# Az escape karakter \\
#
# A kikommentelésre az ALT+7 : \` karakterbő 3 db szolgál tehát: \`\`\`  ezet a szöveg elején és végén kell alkalmazni
#
# Ezt kell beírni:
# ```
# # 1. szintű címsor
# ## 2. szintű címsor
# ### 3. szintű...
# #### 4. szintű...
# ##### 5. szintű...
# ###### 6. szintű címsor
# ```
# Ez a hatása:
#
# # 1. szintű címsor
# ## 2. szintű címsor
# ### 3. szintű...
# #### 4. szintű...
# ##### 5. szintű...
# ###### 6. szintű címsor

# %% [markdown]
# ### 2 Listák
#
# Markdown cellákban ha - jellel kezdünk sorokat, akkor azt a Markdown értelmező listába fogja rendezni:
#
# Ezt kell beírni:
# ```
# - ez elment vadászni
# - ez meglőtte
# - ez haza vitte
# ```
#
# Ez a hatása:
# - ez elment vadászni
# - ez meglőtte
# - ez haza vitte
#
# Ha számokkal kedjük a sorokat, akkor számozott listát kapunk
#
# Ezt kell beírni:
# ```
#  1. megérett a meggy
#  2. csipkebokor vessző
#  3. te leszel a párom
# ```
#
# Ez a hatása:
#  1. megérett a meggy
#  2. csipkebokor vessző
#  3. te leszel a párom

# %% [markdown]
# ### 2 Karakterformázás
#
# Ezt kell beírni:
# ```
# Félkövér szöveg előállítása * karakterekkel: **félkövér** szöveg.
# Félkövér szöveg előállítása _ karakterekkel: __félkövér__ szöveg.
# Dőlt betűs szöveg előállítása * karakterekkel: *dőlt betűs* szöveg.
# Dőlt betűs szöveg előállítása _ karakterekkel: _dőlt betűs_ szöveg.
# Áthúzott szöveg előállítása ~ (tilde) karakterekkel: ~~áthúzott~~ szöveg.
# ```
#
# Ez a hatása:
# Félkövér szöveg előállítása * karakterekkel: **félkövér** szöveg.
# Félkövér szöveg előállítása _ karakterekkel: __félkövér__ szöveg.
# Dőlt betűs szöveg előállítása * karakterekkel: *dőlt betűs* szöveg.
# Dőlt betűs szöveg előállítása _ karakterekkel: _dőlt betűs_ szöveg.
# Áthúzott szöveg előállítása ~ (tilde) karakterekkel: ~~áthúzott~~ szöveg.
#
#
# ---
#
# ### 3 - speciális listák készítése
#
# #### Számozott lista
#
# Ezt kell beírni:
# ```
# 1. Első...
# 2. Második...
# 3. Harmadik listaelem
# ```
#
# Ez a hatása:
# 1. Első...
# 2. Második...
# 3. Harmadik listaelem
#
#
#
# A - helyett * vagy + jel is használható...
#
# - Első...
# - Második...
# - Harmadik listaelem
#
#
# #### Többszintű lista
#
# Ezt kell beírni:
# ```
# - Első szint...      (kötőjel + szóköz + szöveg )
#   - Második szint... (két szóköz + kötőjel + szóköz + szöveg)
#   - Második szint... (két szóköz + kötőjel + szóköz + szöveg)
# - Első szint...
#   1. Második szint...
#   2. Második szint...
# ```
#
# Ez a hatása:
#
# - Első szint...      (kötőjel + szóköz + szöveg )
#   - Második szint... (két szóköz + kötőjel + szóköz + szöveg)
#   - Második szint... (két szóköz + kötőjel + szóköz + szöveg)
# - Első szint...
#   1. Második szint...
#   2. Második szint...
#
# ---
#
#
# #### Behúzás
#
#
# \*literal asterisks\*
#  *literal asterisks*
#
#
#
# Ezt kell beírni:
# ```
# > Bejlebb húzott szöveg
# > szepen eltagolódik
# ```
#
# Ez a hatása:
# > Bejlebb húzott szöveg
# > szepen eltagolódik
#
#
# ### 4 - Linkek használata
#
#
# Ezt kell beírni:
# ```
# A < > jelek között megadott link látható és kattintható - <https://klajosw.blogspot.com/>
#
# Inline-stílus: csak a szöveg látszik és kattintható - [Minta](https://klajosw.blogspot.com/)
# ```
#
# Ez a hatása:
# A < > jelek között megadott link látható és kattintható - <https://klajosw.blogspot.com/>
#
# Inline-stílus: csak a szöveg látszik és kattintható - [Minta](https://klajosw.blogspot.com/)
#
# ---
#
# ### 5 - Képek beillesztése
#
# Ezt kell beírni:
# ```
# ![](https://raw.githubusercontent.com/klajosw/python/master/kl_mie_python_logo_100.jpg)
#
# ![](https://raw.githubusercontent.com/klajosw/python/master/kl_mie_python_logo_250.jpg)
# ```
#
#
# Ez a hatása:
# ![](https://raw.githubusercontent.com/klajosw/python/master/kl_mie_python_logo_100.jpg)
#
# ![](https://raw.githubusercontent.com/klajosw/python/master/kl_mie_python_logo_250.jpg)
#
# ---
#
# ### 6 - Forráskód beillesztése
#
#
# Inline `kódrészlet` beillesztéséhez az <AltGr-7> back-tick karakter használható.
#
# Inline kódrészlet beillesztése: az back-tick karakterek közé írt szöveg kódrészlet típusú lesz...
#
#
#
# #### Többsoros kódblokkokat így illeszthetünk be
#
# Ezt írd be:
# \`\`\`python
# print "Hello World"
# \`\`\`
#
#
# Ez látszik:
# ```python
# print "Hello World"
# ```
#
# Ezt írd be:
# \`\`\`C#
# /* egy kis megjegyzés */
# int counter = 0;
# counter++;
# \`\`\`
#
#
#
# Ez látszik:
# ```C#
# /* egy kis megjegyzés */
# int counter = 0;
# counter++;
# ```
#
#
# Ezt írd be:
# \`\`\`javascript
# /* egy kis megjegyzés */
# var szamlalo = 100; // innen indul
# szamlalo++;
#
# console.log("Hello World")
# \`\`\`
#
# Ez látszik:
# ```javascript
# /* egy kis megjegyzés */
# var szamlalo = 100; // innen indul
# szamlalo++;
#
# console.log("Hello World")
# ```
#
#
#
# Ez a hatása: (Amennyiben nincs meghatározva a nyelv, nem lesz színezve a kód ..)
#
#
# /* c# kód */
# int counter = 0;
# counter++;
#
#
# // javascript kód
# var szamlalo = 100;
# szamlalo++;
#
#
#
# // bash kód
# $ ls -al
#
#
#
# ---
#
#
# ### 7 - Táblázatok előállítása
#
#
# #### Igazítás nélkül:
#
# Ezt kell beírni:
# ```
# | Kód | Név | fizetés |
# | --- | --- | --- |
# | D01 | Gipsz Jakab | 300.000 |
# ```
#
#
# Ez a hatása:
#
# | Kód | Név | fizetés |
# | --- | --- | --- |
# | D01 | Gipsz Jakab | 300.000 |
#
#
#
#
#
# #### Igazítással...
#
#
# ```
# | Kód | Név | Fizetés |
# | :--- | :---: | ---: |
# | D01 | Gipsz Jakab | 300.000 |
# | D02 | Csíkszentmihályi Mihály | 1.222.000 |
#
# ```
#
# Ez a hatása:
#
# | Kód | Név | Fizetés |
# | :--- | :---: | ---: |
# | D01 | Gipsz Jakab | 300.000 |
# | D02 | Csíkszentmihályi Mihály | 1.222.000 |
#
# Balra igazított	Középre igazított	Jobbra igazított
#
# ---
# #### HTML tábla formázás
#
#
# Ezt írod be:
# ```
# <table>
# <tr>
# <th>Header 1</th>
# <th>Header 2</th>
# </tr>
# <tr>
# <td>row 1, cell 1</td>
# <td>row 1, cell 2</td>
# </tr>
# <tr>
# <td>row 2, cell 1</td>
# <td>row 2, cell 2</td>
# </tr>
# </table>
# ```
#
#
# Ezt látod:
# <table>
# <tr>
# <th>Header 1</th>
# <th>Header 2</th>
# </tr>
# <tr>
# <td>row 1, cell 1</td>
# <td>row 1, cell 2</td>
# </tr>
# <tr>
# <td>row 2, cell 1</td>
# <td>row 2, cell 2</td>
# </tr>
# </table>
#
# ---
#
# ### 8 - Blokk jelzés/behúzás alkalmazása
#
# Hasonló megjelenés érhető el ezzel, mint mikor egy beérkezett e-mail-re választ írunk.
# ```
# > Ez a szövegrész
# egy kissé beljebb
# kezdődik majd...
#
# Ez pedig már egy normál pozícióbal lévő szöveg...
# ```
# > Ez a szövegrész
# egy kissé beljebb
# kezdődik majd...
#
# Ez pedig már egy normál pozícióbal lévő szöveg...
#
#
# (A behúzás kikapcsolásához egy üres sor beillesztése szükséges)
#
#
# ---
#
# ### 9 - Vízszintes elválasztó vonal beszúrása
#
# ```
#
# Kötőjelekkel
#
# ---
#
# Csillag karakterekkel
#
# ***
#
#
# Aláhúzás jelekkel
#
# ___
#
#
# ```
#
# Kötőjelekkel
#
# ---
#
#
# Csillag karakterekkel
#
# ***
#
#
# Aláhúzás jelekkel
#
# ___
#
#
#
# ---
#
# ```
# *literal asterisks* literal asterisks
# ```
#
# *literal asterisks* literal asterisks
#
#
# ---
#
#
# ### 10 - Feladatlista készítése
#
# Ezt kell beírni:
# ```
# - [x] A HTML elsajátítása...
# - [ ] CSS használat megismerése...
# - [ ] Komplex weboldal készítése... (HTML+CSS)
# ```
#
# Ezt látod:
# - [x] A HTML elsajátítása...
# - [ ] CSS használat megismerése...
# - [ ] Komplex weboldal készítése... (HTML+CSS)

# %% [markdown]
# ## Táblázatok
#
# Markdown-ban | és - karakterek segítségével meghatározott módon körbehatárolt szövegrészlet segítségével írhatunk táblázatokat. Például így:
#
# ```
# **Név**|**Oszályzat**
# -------|-------------
# Pisti  | 4
# Géza   | 3
# Gizi   | 5
# ```
#
#
# **Név**|**Oszályzat**
# -------|-------------
# Pisti  | 4
# Géza   | 3
# Gizi   | 5

# %% [markdown]
# ### Képek, Linkek
#
# A feladatok megírása során szükséges lehet bizonyos kérdéseknek utánanézni az interneten. Ha egy hasznos leírást találunk valahol, akkor arra Markdown-ban így [link neve](http://www.hasznos-link.hu) hivatkozhatunk.
#
# Ha az interneten vagy a dokumentum saját könyvtárstruktúrájában lévő képet akarunk Markdown cellában mejeleníteni, azt pedig így tehetjük meg:
#
# <p align="left">
#     <img src="https://raw.githubusercontent.com/klajosw/python/master/kl_mie_python_logo_250.jpg"
#          align="left" width="251" height="251">
#     <br />
# </p>
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
#
# ![KL_PY_LOGO](https://raw.githubusercontent.com/klajosw/python/master/kl_mie_python_logo_250.jpg)
#
#
# <br />
# <br />
#
# ---

# %% [markdown]
# ## Képletek írása
# Néhány feladat értelmezésénél szükséges lehet a feladat megoldásához vezető matematikai formulák ismertetése.
#
#
# Ha Markdown-ban
# ```$... $ ```
# jelek közé teszünk megfelelő szintaxisú szöveget, akkor szép matematikai képleteket tudunk írni, például ilyeneket, hogy
# ```
# $\sin(\alpha+\beta)=\sin(\alpha)\cos(\beta)+\cos(\alpha)\sin(\beta)$
# ```
#
# $\sin(\alpha+\beta)=\sin(\alpha)\cos(\beta)+\cos(\alpha)\sin(\beta)$
#
#
#
#
# Ha egy képletet nagyon ki akarunk emelni a szövegből, akkor tegyük két ```$$ ...$$``` jel közé!
# ```
# $$E=mc^2$$
# ```
#
# $$E=mc^2$$
#
#
# ### Tekintsük át néhány további képlet formázással kapcsolatos példát:

# %% [markdown]
# 1. Amint a fenti példában is láttuk, görög betűket egy ```$\ ``` -el kezdünk, és angolul nevezzük őket meg.
#
# Például
# ```
# $\alpha$,$\beta$,$\gamma$,$\delta$
# ```
# $\alpha$,$\beta$,$\gamma$,$\delta$
#
#
# 2. Az ismertebb matematikai függvényeket is lehet \\-el kezdeni, de nem muszáj.
# Figyeljük meg a különbséget:
#
# ```
# $\sin(x)$ és $sin(x)$
# ```
# $\sin(x)$ és $sin(x)$
#
#
# 3. Így írhatunk alsó és felső indexeket:
# ```
# $a_i$, $c^2$
# ```
# $a_i$, $c^2$
#
#
#
# 4. Így pedig törteket
# ```
# $\frac{1}{2}$
# ```
# $\frac{1}{2}$
#
#
#
# 5. Egy összegzés
# ```
# $\mathrm{e}^x=\sum_n \frac{x^n}{n!}$
# ```
# $\mathrm{e}^x=\sum_n \frac{x^n}{n!}$
#
#
# Itt a \\mathrm\{\} kifejezés segítségével az e karakter dölt jellegét tudtuk megszüntetni.
#
#
#
# 6. Figyeljük meg a különbséget, ha kettő \$\$-t használunk
# ```
# $$\mathrm{e}^x=\sum_n \frac{x^n}{n!} $$
# ```
# $$\mathrm{e}^x=\sum_n \frac{x^n}{n!} $$
#
#
#
# 7. Integrálni, deriválni és parciálisan deriválni pedig így tudunk:
# ```
# $$\int \mathrm{e}^x \mathrm{d} x=\mathrm{e}^x+C$$ $$\frac{\mathrm{d}\mathrm{e}^x}{ \mathrm{d} x}=\mathrm{e}^x$$
# ```
# $$\int \mathrm{e}^x \mathrm{d} x=\mathrm{e}^x+C$$ $$\frac{\mathrm{d}\mathrm{e}^x}{ \mathrm{d} x}=\mathrm{e}^x$$
#
#
#
# ```
# $$\frac{\partial\mathrm{e}^x}{ \partial x}=\partial_x \mathrm{e}^x=\mathrm{e}^x$$
# ```
# $$\frac{\partial\mathrm{e}^x}{ \partial x}=\partial_x \mathrm{e}^x=\mathrm{e}^x$$
#
#
#
# 8. Itt egy pár példa vastag betűs vektorokra
# ```
# $$\mathbf{a}\cdot\mathbf{b}=\sum_{i=1}^3 a_ib_i$$
# ```
# $$\mathbf{a}\cdot\mathbf{b}=\sum_{i=1}^3 a_ib_i$$
#
#
#
#
# 9. Itt pedig egy példa felülvonásra
# ```
# $$\overline{x}=\frac{1}{N}\sum_{i=1}^Nx_i$$
# ```
#
# $$\overline{x}=\frac{1}{N}\sum_{i=1}^Nx_i$$
#
#
# 10. Gyökjelet pedig így lehet írni
# ```
# $\gamma=\sqrt{1-v^2/c^2}$
# ```
# $\gamma=\sqrt{1-v^2/c^2}$
#
#
#
#
#
#
#
#
#
# Végül pedig egy mindenkit izgató kérdés:
#
# ```
# $$\frac{1}{2}x+b_u\cdot x=?$$
# ```
#
# $$\frac{1}{2}x+b_u\cdot x=?$$
#
#
# .
