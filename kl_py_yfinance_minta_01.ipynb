# %% [markdown]
# <a href="https://colab.research.google.com/github/klajosw/python/blob/master/kl_py_yfinance_minta_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p align="left">
#     <img src="https://raw.githubusercontent.com/klajosw/python/master/kl_mie_python_logo_250.jpg"
#          align="left" width="251" height="251">
#
# </p>
#
#
# <p> </p>
#
#
#
# # Python pénzügyi számítások
#
# <https://klajosw.blogspot.com/>

# %%
import yfinance as yf
pfizer = yf.Ticker("PFE")
#print('-----------------------')
#print(pfizer.info)
old  =  pfizer.history(start="2010-01-01",  end="2020-07-21")
print(old.head())
print('-----------------------')
print(pfizer.actions)  # show actions (dividends, splits)
print('-----------------------')
print(pfizer.dividends)  # show dividends
print('-----------------------')
print(pfizer.splits)  # show splits
print('-----------------------')
print(pfizer.sustainability)  # show sustainability
print('-----------------------')
print(pfizer.recommendations)  # show sustainability
print('-----------------------')
print(pfizer.isin)  # show ISIN(International Securities Identification Number) 
print('-----------------------')
# Out:
#                  Open       High        Low      Close    Volume  Dividends  \
# Date
# 2009-12-31  11.161700  11.216325  11.040311  11.040311  27063136        0.0
# 2010-01-04  11.088867  11.495520  11.070660  11.489450  54898644        0.0
# 2010-01-05  11.483380  11.489449  11.258811  11.325575  45714931        0.0
# 2010-01-06  11.325576  11.416617  11.234534  11.289159  43640975        0.0
# 2010-01-07  11.313437  11.331646  11.204187  11.246674  41557112        0.0
#
#             Stock Splits
# Date
# 2009-12-31             0
# 2010-01-04             0
# 2010-01-05             0
# 2010-01-06             0
# 2010-01-07             0
# -----------------------
#             Dividends  Stock Splits
# Date
# 2010-02-03   0.170778           0.0
# 2010-05-05   0.170778           0.0
# 2010-08-04   0.170778           0.0
# 2010-11-04   0.170778           0.0
# 2011-02-02   0.189753           0.0
# 2011-05-11   0.189753           0.0
# 2011-08-03   0.189753           0.0
# ...

# %%
old = old.reset_index()
for i in ['Open', 'High', 'Close', 'Low']: 
      old[i]  =  old[i].astype('float64')

# %%
import plotly.graph_objects as go
fig = go.Figure(data=[go.Candlestick(
    x=old['Date'], 
    open=old['Open'],
    high=old['High'],
    low=old['Low'],
    close=old['Close'])])
fig.show()
# Out:
# <div>                            <div id="24260a0a-aedd-41e9-a2cd-1d00ef841435" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("24260a0a-aedd-41e9-a2cd-1d00ef841435")) {                    Plotly.newPlot(                        "24260a0a-aedd-41e9-a2cd-1d00ef841435",                        [{"close":[11.040310859680176,11.489450454711914,11.32557487487793,11.289158821105957,11.246673583984375,11.337715148925781,11.428755760192871,11.39233684539795,11.659394264221191,11.762575149536133,11.829339027404785,12.13887882232666,12.102463722229004,11.677600860595703,11.507660865783691,11.44089412689209,11.398406982421875,11.531938552856445,11.307365417480469,11.32557487487793,11.404480934143066,11.677600860595703,11.408023834228516,11.046546936035156,11.003
# ...

# %%
import plotly.express as px
fig = px.line(old, 
              x="Date", 
              y="Open", 
              title='PFizer Stock Prices 2021')
fig.show()
# Out:
# <div>                            <div id="61b2b969-3685-4bf0-8910-e37182745000" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("61b2b969-3685-4bf0-8910-e37182745000")) {                    Plotly.newPlot(                        "61b2b969-3685-4bf0-8910-e37182745000",                        [{"hovertemplate":"Date=%{x}<br>Open=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2009-12-31T00:00:00","2010-01-04T00:00:00","2010-01-05T00:00:00","2010-01-06T00:00:00","2010-01-07T00:00:00","2010-01-08T00:00:00","2010-01-11T00:00:00","2010-01-12T00:00:00","2010-01-13T00:00:00","2010-01-14T00:00:00","2010-01-15T00:00:00","2010-01-19T00:00:00","2010-01-
# ...

# %%
# OHLC(Open, High, Low, and Close) charts
fig = go.Figure(data=go.Ohlc(
    x=old['Date'],
    open=old['Open'],
    high=old['High'],
    low=old['Low'],
    close=old['Close']))
fig.show()
# Out:
# <div>                            <div id="9d12f9ce-9db9-4d9e-9117-74ea2813305c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9d12f9ce-9db9-4d9e-9117-74ea2813305c")) {                    Plotly.newPlot(                        "9d12f9ce-9db9-4d9e-9117-74ea2813305c",                        [{"close":[11.040310859680176,11.489450454711914,11.32557487487793,11.289158821105957,11.246673583984375,11.337715148925781,11.428755760192871,11.39233684539795,11.659394264221191,11.762575149536133,11.829339027404785,12.13887882232666,12.102463722229004,11.677600860595703,11.507660865783691,11.44089412689209,11.398406982421875,11.531938552856445,11.307365417480469,11.32557487487793,11.404480934143066,11.677600860595703,11.408023834228516,11.046546936035156,11.003
# ...

# %%
import yfinance as yf

aapl = yf.Ticker("aapl")
aapl
# Out:
# yfinance.Ticker object <AAPL>

# %%
import yfinance as yf

aapl = yf.Ticker("aapl")

# get stock info
aapl_historical = aapl.history(start="2020-06-02", end="2020-06-07", interval="1m")
aapl_historical
# Out:
#                              Open    High     Low   Close  Volume  Dividends  \
# Datetime
# 2020-06-02 09:30:00-04:00  320.74  321.68  320.62  321.22  952792          0
# 2020-06-02 09:31:00-04:00  321.23  321.31  320.78  321.03   90413          0
# 2020-06-02 09:32:00-04:00  321.02  321.93  321.02  321.67  192949          0
# 2020-06-02 09:33:00-04:00  321.71  321.74  321.28  321.44  113366          0
# 2020-06-02 09:34:00-04:00  321.43  321.94  321.43  321.55  101503          0
# ...                           ...     ...     ...     ...     ...        ...
# 2020-06-05 15:55:00-04:00  330.62  330.88  330.47  330.76  187683          0
# 2020-06-05 15:56:00-04:00  330.75  330.81  330.35  330.50  153105          0
# 2020-06-05 15:57:00-04:00  330.50  330.80  330.40  330.45  144010          0
# 2020-06-05 15:58:00-04:00  330.45  330.99  330.35  330.93  253691          0
# 2020-06-05 15:59:00-04:00  330.92  331.63  330.91  331.63  473898          0
#
# ...

# %%
tickers = yf.Tickers('msft aapl goog')

# %%
tickers
# Out:
# yfinance.Tickers object <MSFT,AAPL,GOOG>

# %%
data = yf.download("AMZN AAPL GOOG", start="2017-01-01", end="2017-04-30", group_by = 'column')
data
# Out:
# [*********************100%***********************]  3 of 3 completed
#             Adj Close                              Close              \
#                  AAPL        AMZN        GOOG       AAPL        AMZN
# Date
# 2017-01-03  27.332472  753.669983  786.140015  29.037500  753.669983
# 2017-01-04  27.301882  757.179993  786.900024  29.004999  757.179993
# 2017-01-05  27.440718  780.450012  794.020020  29.152500  780.450012
# 2017-01-06  27.746632  795.989990  806.150024  29.477501  795.989990
# 2017-01-09  28.000776  796.919983  806.650024  29.747499  796.919983
# ...               ...         ...         ...        ...         ...
# 2017-04-24  33.947983  907.409973  862.760010  35.910000  907.409973
# 2017-04-25  34.158321  907.619995  872.299988  36.132500  907.619995
# 2017-04-26  33.957428  909.289978  871.729980  35.919998  909.289978
# 2017-04-27  33.983433  918.380005  874.250000  35.947498  918.380005
# ...

# %%
data = yf.download("AMZN AAPL GOOG", start="2017-01-01", end="2017-04-30", group_by='tickers')
data
# Out:
# [*********************100%***********************]  3 of 3 completed
#                   AMZN                                                  \
#                   Open        High         Low       Close   Adj Close
# Date
# 2017-01-03  757.919983  758.760010  747.700012  753.669983  753.669983
# 2017-01-04  758.390015  759.679993  754.200012  757.179993  757.179993
# 2017-01-05  761.549988  782.400024  760.260010  780.450012  780.450012
# 2017-01-06  782.359985  799.440002  778.479980  795.989990  795.989990
# 2017-01-09  798.000000  801.770020  791.770020  796.919983  796.919983
# ...                ...         ...         ...         ...         ...
# 2017-04-24  908.679993  909.989990  903.820007  907.409973  907.409973
# 2017-04-25  907.039978  909.479980  903.000000  907.619995  907.619995
# 2017-04-26  910.299988  915.750000  907.559998  909.289978  909.289978
# 2017-04-27  914.390015  921.859985  912.109985  918.380005  918.380005
# ...

# %%
aapl = yf.Ticker("aapl") 
aapl.info
# Out:
# {'zip': '95014',
#  'sector': 'Technology',
#  'fullTimeEmployees': 154000,
# ...

# %%
aapl = yf.Ticker("aapl")
aapl.info['forwardPE']
# Out:
# 23.081427

# %%
aapl.info['dividendRate']
# Out:
# 3.2800000000000002

# %%
aapl.dividends
# Out:
# Date
# 1987-05-11    0.00214
# 1987-08-10    0.00214
# 1987-11-17    0.00286
# 1988-02-12    0.00286
# 1988-05-16    0.00286
#                ...
# 2019-05-10    0.77000
# 2019-08-09    0.77000
# 2019-11-07    0.77000
# 2020-02-07    0.77000
# 2020-05-08    0.82000
# Name: Dividends, Length: 67, dtype: float64

# %%
import pandas as pd

tickers_list = ["aapl", "goog", "amzn", "BAC", "BA"] # example list
tickers_data = {} # empty dictionary

# %%
for ticker in tickers_list:
    ticker_object = yf.Ticker(ticker)

    #convert info() output from dictionary to dataframe
    temp = pd.DataFrame.from_dict(ticker_object.info, orient="index")
    temp.reset_index(inplace=True)
    temp.columns = ["Attribute", "Recent"]
    
    # add (ticker, dataframe) to main dictionary
    tickers_data[ticker] = temp

tickers_data
# Out:
# {'aapl':                  Attribute                                             Recent
#  0                      zip                                              95014
#  1                   sector                                         Technology
#  2        fullTimeEmployees                                             137000
#  3      longBusinessSummary  Apple Inc. designs, manufactures, and markets ...
#  4                     city                                          Cupertino
#  ..                     ...                                                ...
#  116  sharesShortPriorMonth                                           30124922
#  117               category                                               None
#  118  fiveYearAverageReturn                                               None
#  119     regularMarketPrice                                             344.72
#  120               logo_url                https://logo.clearbit.com/apple.com
#
# ...

# %%
# combine all the info dataframes for each ticker into a single data frame
combined_data = pd.concat(tickers_data)
combined_data = combined_data.reset_index()
combined_data
# Out:
#     level_0  level_1              Attribute  \
# 0      aapl        0                    zip
# 1      aapl        1                 sector
# 2      aapl        2      fullTimeEmployees
# 3      aapl        3    longBusinessSummary
# 4      aapl        4                   city
# ..      ...      ...                    ...
# 600      BA      115  sharesShortPriorMonth
# 601      BA      116               category
# 602      BA      117  fiveYearAverageReturn
# 603      BA      118     regularMarketPrice
# 604      BA      119               logo_url
#
#                                                 Recent
# 0                                                95014
# 1                                           Technology
# 2                                               137000
# 3    Apple Inc. designs, manufactures, and markets ...
# 4                                            Cupertino
# ..                                                 ...
# ...

# %%
del combined_data["level_1"] # clean up unnecessary column
combined_data.columns = ["Ticker", "Attribute", "Recent"] # update column names

combined_data
# Out:
#     Ticker              Attribute  \
# 0     aapl                    zip
# 1     aapl                 sector
# 2     aapl      fullTimeEmployees
# 3     aapl    longBusinessSummary
# 4     aapl                   city
# ..     ...                    ...
# 600     BA  sharesShortPriorMonth
# 601     BA               category
# 602     BA  fiveYearAverageReturn
# 603     BA     regularMarketPrice
# 604     BA               logo_url
#
#                                                 Recent
# 0                                                95014
# 1                                           Technology
# 2                                               137000
# 3    Apple Inc. designs, manufactures, and markets ...
# 4                                            Cupertino
# ..                                                 ...
# 600                                           17995687
# 601                                               None
# ...

# %%
employees = combined_data[combined_data["Attribute"]=="fullTimeEmployees"].reset_index()
del employees["index"] # clean up unnecessary column

employees
# Out:
#   Ticker          Attribute  Recent
# 0   aapl  fullTimeEmployees  137000
# 1   goog  fullTimeEmployees  123048
# 2   amzn  fullTimeEmployees  840400
# 3    BAC  fullTimeEmployees  209000
# 4     BA  fullTimeEmployees  161100

# %%
employees_sorted = employees.sort_values('Recent',ascending=False)
employees_sorted
# Out:
#   Ticker          Attribute  Recent
# 2   amzn  fullTimeEmployees  840400
# 3    BAC  fullTimeEmployees  209000
# 4     BA  fullTimeEmployees  161100
# 0   aapl  fullTimeEmployees  137000
# 1   goog  fullTimeEmployees  123048

# %%
aapl.info["marketCap"]
# Out:
# 1525510701056

# %%
aapl.info["volume"]
# Out:
# 8021292

# %%
aapl.info["averageVolume"]
# Out:
# 42532806

# %%
aapl.info["averageVolume10days"]
# Out:
# 39594100

# %%
aapl_historical = aapl.history(period="max", interval="1wk")
aapl_historical
# Out:
#               Open    High     Low   Close       Volume  Dividends  \
# Date
# 1980-12-08    0.41    0.41    0.41    0.41  117258400.0        0.0
# 1980-12-15    0.39    0.40    0.36    0.40  122533600.0        0.0
# 1980-12-22    0.42    0.50    0.42    0.50   46972800.0        0.0
# 1980-12-29    0.51    0.51    0.48    0.49   54863200.0        0.0
# 1981-01-05    0.48    0.48    0.43    0.45   49476000.0        0.0
# ...            ...     ...     ...     ...          ...        ...
# 2020-05-25  323.50  324.24  313.09  317.94  131406500.0        0.0
# 2020-06-01  317.75  331.75  317.21  331.50  124434000.0        0.0
# 2020-06-08  330.25  354.77  327.32  338.80  202921700.0        0.0
# 2020-06-15  333.25  345.68  332.58  342.99   34642900.0        0.0
# 2020-06-16  333.25  353.02  349.07  351.53   10708995.0        0.0
#
#             Stock Splits
# Date
# 1980-12-08           0.0
# 1980-12-15           0.0
# 1980-12-22           0.0
# 1980-12-29           0.0
# ...

# %%
aapl.info["fiftyTwoWeekHigh"]
# Out:
# 354.77

# %%
aapl.options
# Out:
# ('2020-06-19',
#  '2020-06-26',
#  '2020-07-02',
#  '2020-07-10',
#  '2020-07-17',
#  '2020-07-24',
#  '2020-07-31',
#  '2020-08-21',
#  '2020-09-18',
#  '2020-10-16',
#  '2020-11-20',
#  '2020-12-18',
#  '2021-01-15',
#  '2021-06-18',
#  '2021-09-17',
#  '2022-01-21',
#  '2022-06-17',
#  '2022-09-16')

# %%
# get option chain calls data for specific expiration date
opt = aapl.option_chain(date='2020-07-24')
opt.calls
# Out:
#          contractSymbol       lastTradeDate  strike  lastPrice     bid  \
# 0   AAPL200724C00170000 2020-06-12 13:38:07   170.0     175.11  178.50
# 1   AAPL200724C00230000 2020-06-09 19:19:41   230.0     115.11  118.35
# 2   AAPL200724C00250000 2020-06-15 15:35:19   250.0      88.60   99.40
# 3   AAPL200724C00255000 2020-06-12 13:50:07   255.0      92.60   93.60
# 4   AAPL200724C00260000 2020-06-16 13:46:57   260.0      93.00   88.80
# 5   AAPL200724C00265000 2020-06-16 14:49:37   265.0      85.98   83.20
# 6   AAPL200724C00270000 2020-06-10 14:26:57   270.0      80.50   79.70
# 7   AAPL200724C00275000 2020-06-12 14:44:44   275.0      67.92   74.30
# 8   AAPL200724C00280000 2020-06-12 17:59:03   280.0      59.02   69.60
# 9   AAPL200724C00285000 2020-06-10 18:32:31   285.0      70.35   64.60
# 10  AAPL200724C00290000 2020-06-15 16:22:57   290.0      52.80   59.85
# 11  AAPL200724C00295000 2020-06-10 19:12:42   295.0      59.85   55.30
# ...

# %%
opt.puts
# Out:
#          contractSymbol       lastTradeDate  strike  lastPrice    bid    ask  \
# 0   AAPL200724P00180000 2020-06-15 14:17:59   180.0       0.20   0.00   0.18
# 1   AAPL200724P00190000 2020-06-15 16:28:26   190.0       0.18   0.00   0.22
# 2   AAPL200724P00195000 2020-06-15 04:13:08   195.0       0.39   0.00   0.24
# 3   AAPL200724P00200000 2020-06-15 14:51:12   200.0       0.40   0.03   0.27
# 4   AAPL200724P00205000 2020-06-12 17:35:31   205.0       0.55   0.06   0.31
# 5   AAPL200724P00210000 2020-06-15 18:07:35   210.0       0.33   0.09   0.34
# 6   AAPL200724P00215000 2020-06-12 14:35:13   215.0       0.32   0.13   0.36
# 7   AAPL200724P00220000 2020-06-16 14:19:25   220.0       0.28   0.15   0.43
# 8   AAPL200724P00225000 2020-06-15 17:48:53   225.0       0.50   0.29   0.42
# 9   AAPL200724P00230000 2020-06-16 13:41:27   230.0       0.31   0.27   0.48
# 10  AAPL200724P00235000 2020-06-15 19:02:49   235.0       0.55   0.33   0.54
# ...

# %%
opt
# Out:
# Options(calls=         contractSymbol       lastTradeDate  strike  lastPrice     bid  \
# 0   AAPL200724C00170000 2020-06-12 13:38:07   170.0     175.11  178.50
# 1   AAPL200724C00230000 2020-06-09 19:19:41   230.0     115.11  118.35
# 2   AAPL200724C00250000 2020-06-15 15:35:19   250.0      88.60   99.40
# 3   AAPL200724C00255000 2020-06-12 13:50:07   255.0      92.60   93.60
# 4   AAPL200724C00260000 2020-06-16 13:46:57   260.0      93.00   88.80
# 5   AAPL200724C00265000 2020-06-16 14:49:37   265.0      85.98   83.20
# 6   AAPL200724C00270000 2020-06-10 14:26:57   270.0      80.50   79.70
# 7   AAPL200724C00275000 2020-06-12 14:44:44   275.0      67.92   74.30
# 8   AAPL200724C00280000 2020-06-12 17:59:03   280.0      59.02   69.60
# 9   AAPL200724C00285000 2020-06-10 18:32:31   285.0      70.35   64.60
# 10  AAPL200724C00290000 2020-06-15 16:22:57   290.0      52.80   59.85
# 11  AAPL200724C00295000 2020-06-10 19:12:42   295.0      59.85   55.30
# ...

# %%
#### OTHER METHODS NOT USED IN ARTICLE ####

# %%
# show actions (dividends, splits)
aapl.actions
# Out:
#             Dividends  Stock Splits
# Date
# 1987-05-11    0.00214           0.0
# 1987-06-16    0.00000           2.0
# 1987-08-10    0.00214           0.0
# 1987-11-17    0.00286           0.0
# 1988-02-12    0.00286           0.0
# ...               ...           ...
# 2019-05-10    0.77000           0.0
# 2019-08-09    0.77000           0.0
# 2019-11-07    0.77000           0.0
# 2020-02-07    0.77000           0.0
# 2020-05-08    0.82000           0.0
#
# [71 rows x 2 columns]

# %%
# show splits
aapl.splits
# Out:
# Date
# 1987-06-16    2.0
# 2000-06-21    2.0
# 2005-02-28    2.0
# 2014-06-09    7.0
# Name: Stock Splits, dtype: float64

# %%
# show financials BROKEN
aapl.financials
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
# show quarterly_financials BROKEN
aapl.quarterly_financials
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
# show major holders 
aapl.major_holders
# Out:
#         0                                      1
# 0   0.07%        % of Shares Held by All Insider
# 1  62.12%       % of Shares Held by Institutions
# 2  62.16%        % of Float Held by Institutions
# 3    4296  Number of Institutions Holding Shares

# %%
# show institutional holders
aapl.institutional_holders
# Out:
#                               Holder     Shares Date Reported   % Out  \
# 0         Vanguard Group, Inc. (The)  336728608    2020-03-30  0.0777
# 1                     Blackrock Inc.  274684501    2020-03-30  0.0634
# 2            Berkshire Hathaway, Inc  245155566    2020-03-30  0.0566
# 3           State Street Corporation  180558954    2020-03-30  0.0417
# 4                Advisor Group, Inc.  116768396    2020-03-30  0.0269
# 5                           FMR, LLC   93376233    2020-03-30  0.0215
# 6      Geode Capital Management, LLC   64178586    2020-03-30  0.0148
# 7      Price (T.Rowe) Associates Inc   56203762    2020-03-30  0.0130
# 8         Northern Trust Corporation   53859611    2020-03-30  0.0124
# 9  Norges Bank Investment Management   46856273    2019-12-30  0.0108
#
#          Value
# 0  85626717728
# 1  69849521759
# 2  62340608878
# 3  45914336412
# 4  29693035418
# 5  23744642289
# 6  16319972633
# 7  14292054638
# 8  13695960481
# 9  13759344566

# %%
# show balance sheet BROKEN
aapl.balance_sheet
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
# BROKEN
aapl.quarterly_balance_sheet
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
# show cashflow BROKEN
aapl.cashflow
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
# BROKEN
aapl.quarterly_cashflow
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
# show earnings BROKEN
aapl.earnings
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
# BROKEN
aapl.quarterly_earnings
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
# show sustainability BROKEN
aapl.sustainability
# Out:
#                                      Value
# 2020-3
# palmOil                              False
# controversialWeapons                 False
# gambling                             False
# socialScore                             13
# nuclear                              False
# furLeather                           False
# alcoholic                            False
# gmo                                  False
# catholic                             False
# socialPercentile                         0
# peerCount                               57
# governanceScore                      10.26
# environmentPercentile                    0
# animalTesting                        False
# tobacco                              False
# totalEsg                             23.82
# highestControversy                       3
# esgPerformance                    AVG_PERF
# coal                                 False
# pesticides                           False
# adult                                False
# ...

# %%
# show analysts recommendations
aapl.recommendations
# Out:
#                                   Firm    To Grade From Grade Action
# Date
# 2012-02-09 08:17:00  Canaccord Genuity         Buy              main
# 2012-03-08 07:33:00     FBN Securities  Outperform              main
# 2012-03-13 06:08:00          Jefferies         Buy              main
# 2012-03-14 06:13:00     Morgan Stanley  Overweight              main
# 2012-03-14 08:21:00  Canaccord Genuity         Buy              main
# ...                                ...         ...        ...    ...
# 2020-06-05 12:43:04            Wedbush  Outperform              main
# 2020-06-10 11:19:05      Deutsche Bank         Buy              main
# 2020-06-11 11:04:46               HSBC        Hold     Reduce     up
# 2020-06-11 12:07:07        Wells Fargo  Overweight              main
# 2020-06-11 12:16:06  B of A Securities         Buy              main
#
# [705 rows x 4 columns]

# %%
# show next event (earnings, etc)
aapl.calendar
# Out:
#                                     0                    1
# Earnings Date     2020-07-28 00:00:00  2020-08-03 00:00:00
# Earnings Average                 1.99                 1.99
# Earnings Low                     1.55                 1.55
# Earnings High                     2.3                  2.3
# Revenue Average           51368400000          51368400000
# Revenue Low               42799000000          42799000000
# Revenue High              54517500000          54517500000

# %%
# show ISIN code - *experimental*
# ISIN = International Securities Identification Number
aapl.isin
# Out:
# 'US0378331005'

# %%
# show options expirations
aapl.options
# Out:
# ('2020-06-19',
#  '2020-06-26',
#  '2020-07-02',
#  '2020-07-10',
#  '2020-07-17',
#  '2020-07-24',
#  '2020-07-31',
#  '2020-08-21',
#  '2020-09-18',
#  '2020-10-16',
#  '2020-11-20',
#  '2020-12-18',
#  '2021-01-15',
#  '2021-06-18',
#  '2021-09-17',
#  '2022-01-21',
#  '2022-06-17',
#  '2022-09-16')

# %%
# get option chain for specific expiration
opt = aapl.option_chain()
opt
# Out:
# Options(calls=         contractSymbol       lastTradeDate  strike  lastPrice     bid  \
# 0   AAPL200619C00075000 2020-06-15 19:36:28    75.0     266.60  277.60
# 1   AAPL200619C00080000 2020-06-15 18:00:55    80.0     261.95  272.60
# 2   AAPL200619C00085000 2020-06-16 13:35:34    85.0     265.35  267.60
# 3   AAPL200619C00090000 2020-06-04 19:53:39    90.0     231.40  258.65
# 4   AAPL200619C00095000 2020-05-28 18:32:40    95.0     227.40  255.70
# ..                  ...                 ...     ...        ...     ...
# 92  AAPL200619C00460000 2020-06-16 13:30:10   460.0       0.02    0.00
# 93  AAPL200619C00470000 2020-06-15 19:08:28   470.0       0.01    0.00
# 94  AAPL200619C00480000 2020-06-15 19:40:30   480.0       0.01    0.00
# 95  AAPL200619C00490000 2020-06-15 13:58:25   490.0       0.01    0.00
# 96  AAPL200619C00500000 2020-06-15 19:40:12   500.0       0.01    0.00
#
#        ask    change  percentChange  volume  openInterest  impliedVolatility  \
# ...
